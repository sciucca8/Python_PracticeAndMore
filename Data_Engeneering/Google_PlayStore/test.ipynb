# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv("GooglePS.csv")

# %%
new_df = df.groupby(by= ["Type"]).apply(lambda x: x.sort_values("Installs", ascending= False).head(5))[["Installs", "App"]]
new_df["Installs"] /= 1_000_000
new_df
# Out:
#            Installs                            App
# Type
# Free 2820    1000.0                    Google News
#      2375    1000.0             Google Street View
#      340     1000.0   Google Chrome: Fast & Secure
#      2775    1000.0        Google Play Movies & TV
#      1950    1000.0                      Instagram
# Paid 3063      10.0                  Hitman Sniper
#      3324      10.0                      Minecraft
#      2534       1.0          Beautiful Widgets Pro
#      8021       1.0  Stickman Legends: Shadow Wars
#      6249       1.0                        Threema

# %%
graph_df = new_df.plot(kind= "bar", x= "App", y= "Installs")
plt.show()
